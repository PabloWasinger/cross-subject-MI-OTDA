# %%
from src.evaluation import (
    calculate_method_accuracies, 
    calculate_method_times,
    calculate_blockwise_accuracy_by_run,
    calculate_blockwise_accuracy_by_subject,
    calculate_blockwise_times_by_run
)
from src.plots import (
    plot_accuracy_table, 
    plot_method_times,
    plot_blockwise_accuracy_by_run,
    plot_blockwise_accuracy_by_subject,
    plot_blockwise_accuracy_evolution
)

# %%
# Calcular accuracies
results_df, summary_df = calculate_method_accuracies(verbose=True)
# Out:
# subject_01_blockwise: 960 trials processed
# subject_02_blockwise: 960 trials processed
# subject_03_blockwise: 960 trials processed
# subject_05_blockwise: 960 trials processed
# subject_06_blockwise: 960 trials processed
# subject_07_blockwise: 960 trials processed
# subject_08_blockwise: 960 trials processed
# subject_09_blockwise: 960 trials processed
#
# Results saved to results/method_accuracies.csv
# Summary saved to results/method_accuracies_summary.csv
#
# Summary:

# %%
# Generar tabla
plot_accuracy_table(verbose=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Generar tabla
# ----> 2 plot_accuracy_table(verbose=True)
#
# File ~/developer/udesa/ML/TP-Final/cross-subject-MI-OTDA/src/plots.py:185, in plot_accuracy_table(csv_file, output_file, verbose)
#     181 columns = ['Method'] + list(df.columns)
#     183 colors = plt.cm.RdYlGn(np.linspace(0.3, 0.9, len(df.index)))
# --> 185 table = ax.table(cellText=cell_text, colLabels=columns, cellLoc='center',
#     186                  loc='center', bbox=[0, 0, 1, 1])
#     188 table.auto_set_font_size(False)
#     189 table.set_fontsize(10)
#
# File ~/anaconda3/envs/otda-mibci/lib/python3.10/site-packages/matplotlib/table.py:761, in table(ax, cellText, cellColours, cellLoc, colWidths, rowLabels, rowColours, rowLoc, colLabels, colColours, colLoc, loc, bbox, edges, **kwargs)
#     758     cellText = cellText.values
# ...

# %%
# Calcular tiempos
times_df = calculate_method_times(verbose=True)

# Generar gráfico
plot_method_times(verbose=True)
# Out:
# subject_01: 120 trials processed
# subject_02: 120 trials processed
# subject_03: 120 trials processed
# subject_05: 120 trials processed
# subject_06: 120 trials processed
# subject_07: 120 trials processed
# subject_08: 120 trials processed
# subject_09: 120 trials processed
#
# Time summary saved to results/method_times.csv
#
# Time Summary:
# SC: 0.0001 ± 0.0000 seconds
# SR: 0.1945 ± 0.0135 seconds
# RPA: 3.8547 ± 0.3929 seconds
# EA: 0.3469 ± 0.0636 seconds
# FOTDA-S: 0.0338 ± 0.0258 seconds
# FOTDA-GL: 0.0199 ± 0.0110 seconds
# BOTDA-S: 0.0141 ± 0.0182 seconds
# BOTDA-GL: 0.0178 ± 0.0087 seconds
# Time table saved to results/method_times.png

# %%
results_df, summary_df = calculate_method_accuracies(results_dir='results_cs_samplewise_1', output_file='results_cs_samplewise_1/method_accuracies.csv', verbose=True)
# Out:
# subject_01: 120 trials processed
# subject_02: 120 trials processed
# subject_03: 120 trials processed
# subject_05: 120 trials processed
# subject_06: 120 trials processed
# subject_07: 120 trials processed
# subject_08: 120 trials processed
# subject_09: 120 trials processed
#
# Results saved to results_cs_samplewise_1/method_accuracies.csv
# Summary saved to results_cs_samplewise_1/method_accuracies_summary.csv
#
# Summary:
# SC: 78.23 ± 15.19%
# SR: 81.56 ± 14.59%
# RPA: 90.00 ± 8.43%
# EA: 87.81 ± 10.91%
# FOTDA-S: 79.48 ± 14.26%
# FOTDA-GL: 80.42 ± 14.41%
# BOTDA-S: 79.17 ± 14.04%
# BOTDA-GL: 88.12 ± 8.67%

# %%
times_df = calculate_method_times(results_dir='results_cs_samplewise_1', output_file='results_cs_samplewise_1/method_times.csv', verbose=True)
# Out:
# subject_01: 120 trials processed
# subject_02: 120 trials processed
# subject_03: 120 trials processed
# subject_05: 120 trials processed
# subject_06: 120 trials processed
# subject_07: 120 trials processed
# subject_08: 120 trials processed
# subject_09: 120 trials processed
#
# Time summary saved to results_cs_samplewise_1/method_times.csv
#
# Time Summary:
# SC: 0.0001 ± 0.0000 seconds
# SR: 0.1947 ± 0.0116 seconds
# RPA: 3.8444 ± 0.3910 seconds
# EA: 0.3417 ± 0.0563 seconds
# FOTDA-S: 0.0335 ± 0.0260 seconds
# FOTDA-GL: 0.0140 ± 0.0107 seconds
# BOTDA-S: 0.0147 ± 0.0164 seconds
# BOTDA-GL: 0.0166 ± 0.0083 seconds

# %%
plot_accuracy_table(csv_file='results_cs_samplewise_1/method_accuracies.csv', output_file='results_cs_samplewise_1/accuracy_table.png', verbose=True)
plot_method_times(csv_file='results_cs_samplewise_1/method_times.csv', output_file='results_cs_samplewise_1/method_times.png', verbose=True)
# Out:
# Table plot saved to results_cs_samplewise_1/accuracy_table.png
# Time table saved to results_cs_samplewise_1/method_times.png

# %% [markdown]
# ## Block-wise Evaluation

# %%
# Accuracy by Run (averaged across subjects)
acc_by_run = calculate_blockwise_accuracy_by_run(verbose=True)
# Out:
# Blockwise accuracy by run saved to results/blockwise_accuracy_by_run.csv
# run           1      2      3      4      5   Mean   Std
# SC        79.17  80.21  81.77  77.60  72.40  78.23  3.60
# SR        82.81  80.73  83.33  82.81  80.21  81.98  1.41
# RPA       79.69  78.12  79.69  75.52  70.83  76.77  3.73
# EA        82.81  84.38  79.17  81.25  77.60  81.04  2.72
# FOTDA-S   80.73  83.33  78.65  81.25  73.96  79.58  3.56
# FOTDA-GL  80.73  82.29  81.25  76.56  75.52  79.27  3.02
# BOTDA-S   79.17  81.77  81.25  77.60  73.96  78.75  3.16
# BOTDA-GL  74.48  82.29  82.29  76.56  75.52  78.23  3.78

# %%
# Accuracy by Subject (averaged across runs)
acc_by_subject = calculate_blockwise_accuracy_by_subject(verbose=True)
# Out:
# Blockwise accuracy by subject saved to results/blockwise_accuracy_by_subject.csv
#             S01    S02    S03    S05    S06    S07    S08    S09   Mean    Std
# SC        88.33  54.17  93.33  67.50  62.50  77.50  92.50  90.00  78.23  15.19
# SR        85.83  60.00  96.67  72.50  70.00  79.17  98.33  93.33  81.98  13.89
# RPA       78.33  55.00  97.50  57.50  64.17  73.33  96.67  91.67  76.77  17.18
# EA        88.33  55.83  97.50  67.50  67.50  85.00  96.67  90.00  81.04  15.43
# FOTDA-S   83.33  58.33  95.00  75.00  66.67  72.50  96.67  89.17  79.58  13.76
# FOTDA-GL  88.33  55.00  95.00  66.67  65.83  78.33  95.00  90.00  79.27  15.22
# BOTDA-S   90.00  55.83  97.50  61.67  65.83  79.17  93.33  86.67  78.75  15.75
# BOTDA-GL  83.33  59.17  96.67  63.33  65.83  75.83  95.83  85.83  78.23  14.53

# %%
# Times by Run
times_by_run = calculate_blockwise_times_by_run(verbose=True)
# Out:
# Blockwise times by run saved to results/blockwise_times_by_run.csv
# run             1        2        3        4        5     Mean
# SC         0.0001   0.0001   0.0001   0.0001   0.0001   0.0001
# SR         0.2280   0.2572   0.2617   0.2413   0.2425   0.2461
# RPA        6.0519   4.6510   4.0241   4.0147   4.1669   4.5817
# EA         0.3134   0.3572   0.3796   0.5272   0.5015   0.4158
# FOTDA-S    5.2816   5.9334  11.2882  14.2287  18.6196  11.0703
# FOTDA-GL  26.1613  29.9157  40.1879  48.9498  54.1221  39.8673
# BOTDA-S    4.4454   5.3636  10.1340  15.1941  18.0489  10.6372
# BOTDA-GL  24.4778  26.6787  36.7988  45.2950  56.0189  37.8538

# %%
# Plot: Accuracy table by Run
plot_blockwise_accuracy_by_run(verbose=True)
# Out:
# Plot saved to results/blockwise_accuracy_by_run.png

# %%
# Plot: Accuracy table by Subject
plot_blockwise_accuracy_by_subject(verbose=True)
# Out:
# Plot saved to results/blockwise_accuracy_by_subject.png

# %%
# Plot: Accuracy evolution across runs
plot_blockwise_accuracy_evolution(verbose=True)
# Out:
# Plot saved to results/blockwise_accuracy_evolution.png
